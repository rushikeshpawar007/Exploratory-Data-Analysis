# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Onyx Data - DataDNA Dataset Challenge - July 2021 - Spotify Tracks.csv')

# %%
df.head(2)
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   22-02-1922         0.645   0.445    0   -13.338     1        0.451
# 1   01-06-1922         0.695   0.263    0   -22.136     1        0.957
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674             0.744     0.151    0.127  104.851               3
# 1         0.797             0.000     0.148    0.655  102.009               1

# %%
df.columns
# Out:
# Index(['id', 'name', 'popularity', 'duration_ms', 'explicit', 'artists',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature'],
#       dtype='object')

# %%
df['artists'] = df['artists'].apply(lambda x:x.replace('[','').replace(']',''))

# %%
df.head(2)
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
#
#    duration_ms  explicit            artists                  id_artists  \
# 0       126903         0              'Uli'  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  'Fernando Pessoa'  ['14jtPCOoNZwquk5wd9DxrY']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   22-02-1922         0.645   0.445    0   -13.338     1        0.451
# 1   01-06-1922         0.695   0.263    0   -22.136     1        0.957
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674             0.744     0.151    0.127  104.851               3
# 1         0.797             0.000     0.148    0.655  102.009               1

# %%
df['artists'] = df['artists'].str.lstrip()

# %%
df['artists'] = df['artists'].str.rstrip()

# %%
df.head(2)
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
#
#    duration_ms  explicit            artists                  id_artists  \
# 0       126903         0              'Uli'  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  'Fernando Pessoa'  ['14jtPCOoNZwquk5wd9DxrY']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   22-02-1922         0.645   0.445    0   -13.338     1        0.451
# 1   01-06-1922         0.695   0.263    0   -22.136     1        0.957
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674             0.744     0.151    0.127  104.851               3
# 1         0.797             0.000     0.148    0.655  102.009               1

# %%
df['artists'] = df['artists'].apply(lambda x:x.replace("'",''))

# %%
df.head(2)
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
#
#    duration_ms  explicit          artists                  id_artists  \
# 0       126903         0              Uli  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  Fernando Pessoa  ['14jtPCOoNZwquk5wd9DxrY']
#
#   release_date  danceability  energy  key  loudness  mode  speechiness  \
# 0   22-02-1922         0.645   0.445    0   -13.338     1        0.451
# 1   01-06-1922         0.695   0.263    0   -22.136     1        0.957
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature
# 0         0.674             0.744     0.151    0.127  104.851               3
# 1         0.797             0.000     0.148    0.655  102.009               1

# %%
df.id.nunique()
# Out:
# 586672

# %%
df['danceability'].value_counts()
# Out:
# 0.6370    1483
# 0.6290    1453
# 0.6020    1446
# 0.5950    1444
# 0.6160    1442
#           ...
# 0.0855       1
# 0.0652       1
# 0.0984       1
# 0.0583       1
# 0.0702       1
# Name: danceability, Length: 1285, dtype: int64

# %%
df.loc[df.danceability == 0.0702,:]
# Out:
#                           id  \
# 8825  6rXlnhh3UVU2Dzl5uYJ940
#
#                                                    name  popularity  \
# 8825  Das Orgel-Büchlein: Gelobet seist du, Jesu Chr...           0
#
#       duration_ms  explicit                                   artists  \
# 8825       130126         0  Johann Sebastian Bach, Albert Schweitzer
#
#                                              id_artists release_date  \
# 8825  ['5aIqB5nVVvmFsvSdExz408', '4n3YrsJmeY6qTYJyGw...   16-04-1905
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 8825        0.0702  0.0947    7   -19.837     1       0.0423         0.923
#
#       instrumentalness  liveness  valence  tempo  time_signature
# 8825             0.894      0.14    0.134  75.23               4

# %%
df['id'].nunique()
# Out:
# 586672

# %%
df['popularity'].nunique()
# Out:
# 101

# %%
gkk = df.groupby('popularity')

# %%
# Out:
#                            id                                    name  \
# 0      35iwgR4jXetI318WEWsa1Q                                   Carve
# 1      021ht4sdgPcrDgSk7JTbKY     Capítulo 2.16 - Banquero Anarquista
# 2      07A5yehtSnoedViJAZkNnc      Vivo para Quererte - Remasterizado
# 3      08FmqUhxtyLTn6pAh6bk45           El Prisionero - Remasterizado
# 4      08y9GfoqCWfOGsKdwojr5e                     Lady of the Evening
# ...                       ...                                     ...
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 93805  7MAibcTli4IisCtbHKrGMh                     Leave The Door Open
# 93806  7Bk0uXKk1uPT0XuQbpFzvs                                    Fiel
#
#        popularity  duration_ms  explicit  \
# 0               6       126903         0
# ...

# %%
df.to_csv('df.csv')
