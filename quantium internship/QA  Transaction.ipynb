# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('QVI_transaction_data.xlsx')

# %%
df.head()
# Out:
#     DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0  43390          1            1000       1         5
# 1  43599          1            1307     348        66
# 2  43605          1            1343     383        61
# 3  43329          2            2373     974        69
# 4  43330          2            2426    1038       108
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES
# 0    Natural Chip        Compny SeaSalt175g         2        6.0
# 1                  CCs Nacho Cheese    175g         3        6.3
# 2    Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 4  Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264836 entries, 0 to 264835
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DATE            264836 non-null  int64
#  1   STORE_NBR       264836 non-null  int64
#  2   LYLTY_CARD_NBR  264836 non-null  int64
#  3   TXN_ID          264836 non-null  int64
#  4   PROD_NBR        264836 non-null  int64
#  5   PROD_NAME       264836 non-null  object
#  6   PROD_QTY        264836 non-null  int64
#  7   TOT_SALES       264836 non-null  float64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 16.2+ MB

# %%
df.isnull().sum()
# Out:
# DATE              0
# STORE_NBR         0
# LYLTY_CARD_NBR    0
# TXN_ID            0
# PROD_NBR          0
# PROD_NAME         0
# PROD_QTY          0
# TOT_SALES         0
# dtype: int64

# %%
df.DATE
# Out:
# 0         43390
# 1         43599
# 2         43605
# 3         43329
# 4         43330
#           ...
# 264831    43533
# 264832    43325
# 264833    43410
# 264834    43461
# 264835    43365
# Name: DATE, Length: 264836, dtype: int64

# %%
df.DATE.nunique()
# Out:
# 364

# %%
DATE_unique = df.DATE.unique()

# %%
DATE_unique
# Out:
# array([43390, 43599, 43605, 43329, 43330, 43604, 43601, 43332, 43602,
#        43603, 43600, 43326, 43328, 43331, 43327, 43633, 43348, 43370,
#        43523, 43543, 43632, 43429, 43414, 43533, 43405, 43537, 43561,
#        43311, 43391, 43409, 43528, 43535, 43576, 43468, 43366, 43624,
#        43313, 43448, 43587, 43474, 43566, 43529, 43369, 43554, 43519,
#        43451, 43564, 43563, 43382, 43407, 43489, 43510, 43627, 43284,
#        43299, 43309, 43552, 43593, 43611, 43526, 43578, 43584, 43357,
#        43494, 43547, 43550, 43318, 43467, 43555, 43294, 43386, 43496,
#        43504, 43520, 43583, 43321, 43446, 43568, 43643, 43646, 43287,
#        43562, 43423, 43434, 43479, 43333, 43508, 43634, 43436, 43458,
#        43463, 43579, 43620, 43622, 43345, 43361, 43482, 43617, 43625,
#        43288, 43352, 43360, 43404, 43290, 43323, 43363, 43399, 43402,
#        43551, 43556, 43365, 43367, 43439, 43518, 43539, 43639, 43292,
# ...

# %%
df2 = df.groupby('DATE')

# %%
df2 = (df.groupby('DATE')).nunique()

# %%
df2
# Out:
#        STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  PROD_NAME  PROD_QTY  \
# DATE
# 43282        219             720     720       110        110         2
# 43283        215             707     707       113        113         2
# 43284        218             717     717       112        112         2
# 43285        210             708     708       113        113         2
# 43286        217             708     708       110        110         2
# ...          ...             ...     ...       ...        ...       ...
# 43642        215             720     720       111        111         2
# 43643        214             707     707       114        114         2
# 43644        213             726     726       114        114         2
# 43645        218             742     742       113        113         2
# 43646        223             739     739       112        112         2
#
#        TOT_SALES
# DATE
# 43282         40
# 43283         41
# 43284         42
# ...

# %%
(df.groupby('STORE_NBR')).nunique()
# Out:
#            DATE  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  PROD_NAME  PROD_QTY  \
# STORE_NBR
# 1           291             345     572       114        114         4
# 2           267             313     505       112        112         4
# 3           361             364    1489        57         57         5
# 4           359             379    1667        57         57         3
# 5           359             238    1358       114        114         5
# ...         ...             ...     ...       ...        ...       ...
# 268         283             333     545       112        112         5
# 269         359             251    1598       114        114         5
# 270         359             243    1608       114        114         5
# 271         349             239    1374       114        114         4
# 272         285             288     561        57         57         3
#
#            TOT_SALES
# STORE_NBR
# 1                 48
# 2                 42
# 3                 29
# ...

# %%
df3 = (df.groupby('TOT_SALES')).nunique()

# %%
df3.sort_values('TOT_SALES', ascending=False)
# Out:
#            DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  PROD_NAME  \
# TOT_SALES
# 650.0         2          1               1       2         1          1
# 29.5          5          7               7       7         1          1
# 28.5         10         11              12      12         4          4
# 27.0         13         34              35      35         6          6
# 25.5          8         14              14      14         3          3
# ...         ...        ...             ...     ...       ...        ...
# 2.1         297        141             722     732         4          4
# 1.9         324        140             918     930         5          5
# 1.8         126         85             175     175         1          1
# 1.7         310        134             703     708         4          4
# 1.5         197        109             354     354         2          2
#
#            PROD_QTY
# TOT_SALES
# 650.0             1
# 29.5              1
# ...

# %%
TOP_1 = df.loc[df['TOT_SALES'] == 650.0,:]
# Out:
#         DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 69762  43331        226          226000  226201         4
# 69763  43605        226          226000  226210         4
#
#                               PROD_NAME  PROD_QTY  TOT_SALES
# 69762  Dorito Corn Chp     Supreme 380g       200      650.0
# 69763  Dorito Corn Chp     Supreme 380g       200      650.0

# %% [markdown]
# Here, we can see that max sales was done by store number 226, total sales done 400 units within 2 days
# name of the product = Dorito Corn Chp Supreme 380g

# %%
df.loc[df['TOT_SALES'] == 29.5,:]
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 5179    43327         94           94148   93390        14
# 55558   43599        190          190113  190914        14
# 69496   43327         49           49303   45789        14
# 117850  43604        194          194308  194516        14
# 150683  43605        118          118021  120799        14
# 171815  43329         24           24095   20797        14
# 184969  43605         44           44350   40394        14
#
#                                      PROD_NAME  PROD_QTY  TOT_SALES
# 5179    Smiths Crnkle Chip  Orgnl Big Bag 380g         5       29.5
# 55558   Smiths Crnkle Chip  Orgnl Big Bag 380g         5       29.5
# 69496   Smiths Crnkle Chip  Orgnl Big Bag 380g         5       29.5
# 117850  Smiths Crnkle Chip  Orgnl Big Bag 380g         5       29.5
# 150683  Smiths Crnkle Chip  Orgnl Big Bag 380g         5       29.5
# 171815  Smiths Crnkle Chip  Orgnl Big Bag 380g         5       29.5
# ...

# %% [markdown]
# Here, we can see that max sales was done by store number 94, 190, 49, 194, 118, 24, 44, total sales done 35 units within 7 days
# name of the product = Smiths Crnkle Chip Orgnl Big Bag 380g

# %%
TOP_1 = df.loc[df['TOT_SALES'] == 650.0,:]

# %%
TOP_2 = df.loc[df['TOT_SALES'] == 29.5,:]

# %%
df.loc[df['TOT_SALES'] == 28.5,:]
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 72      43331         96           96203   96025         7
# 17110   43328        172          172239  174254         7
# 32248   43601         66           66014   63251        23
# 81110   43329        181          181129  183109        23
# 81301   43326        243          243345  247084        16
# 99764   43330        237          237317  241546        20
# 117917  43330        221          221184  220787        16
# 117918  43605        221          221351  221349        23
# 135346  43327        101          101110  100677        16
# 135445  43326        154          154199  154279        20
# 185344  43602        180          180233  182542        23
# 204362  43332        222          222005  221532         7
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES
# 72             Smiths Crinkle      Original 330g         5       28.5
# ...

# %%
df4 = (df.groupby('PROD_NAME')).nunique()

# %%
df4
# Out:
#                                         DATE  STORE_NBR  LYLTY_CARD_NBR  \
# PROD_NAME
# Burger Rings 220g                        355        158            1519
# CCs Nacho Cheese    175g                 359        154            1462
# CCs Original 175g                        360        155            1476
# CCs Tasty Cheese    175g                 358        159            1512
# Cheetos Chs & Bacon Balls 190g           358        161            1450
# ...                                      ...        ...             ...
# WW Sour Cream &OnionStacked Chips 160g   356        157            1445
# WW Supreme Cheese   Corn Chips 200g      358        156            1470
# Woolworths Cheese   Rings 190g           358        157            1482
# Woolworths Medium   Salsa 300g           354        160            1407
# Woolworths Mild     Salsa 300g           358        155            1459
#
#                                         TXN_ID  PROD_NBR  PROD_QTY  TOT_SALES
# PROD_NAME
# ...

# %% [markdown]
# There are total 114 products.

# %%
sns.boxplot(x = df['LYLTY_CARD_NBR'])
# Out:
# <AxesSubplot:xlabel='LYLTY_CARD_NBR'>

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(df.LYLTY_CARD_NBR))
print(z)
# Out:
# [1.66976628 1.6659564  1.66550963 ... 1.69806179 1.69806179 1.6980742 ]

# %%
threshold = 3
print(np.where(z > 3))
q = np.where(z > 3)
# Out:
# (array([  1440,  15676,  19455,  19463,  32030,  39777,  39778,  39794,
#         39795,  53106,  53107,  80809,  96939,  97171,  97172,  97173,
#         99033,  99034, 104927, 105897, 105898, 105899, 115267, 123456,
#        123510, 133253, 135105, 135106, 135734, 140568, 169023, 169026,
#        172311, 191105, 191117, 191118, 215358, 215522, 227371, 228460,
#        238493, 244444, 255925, 256040], dtype=int64),)

# %%
for i in q:
    new = df.drop(df.index[i])
    print(new)
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0       43390          1            1000       1         5
# 1       43599          1            1307     348        66
# 2       43605          1            1343     383        61
# 3       43329          2            2373     974        69
# 4       43330          2            2426    1038       108
# ...       ...        ...             ...     ...       ...
# 264831  43533        272          272319  270088        89
# 264832  43325        272          272358  270154        74
# 264833  43410        272          272379  270187        51
# 264834  43461        272          272379  270188        42
# 264835  43365        272          272380  270189        74
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES
# 0         Natural Chip        Compny SeaSalt175g         2        6.0
# 1                       CCs Nacho Cheese    175g         3        6.3
# ...

# %%
sns.boxplot(x = new['LYLTY_CARD_NBR'])
# Out:
# <AxesSubplot:xlabel='LYLTY_CARD_NBR'>

# %%
new
