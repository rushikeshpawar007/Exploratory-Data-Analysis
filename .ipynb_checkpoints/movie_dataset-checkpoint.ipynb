# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %%
df = pd.read_csv('C:/Users/Rushikesh/Desktop/DataSet/movies.csv')

# %%
#Lets look at the data
df.head()
# Out:
#        budget                                 company country        director  \
# 0   8000000.0           Columbia Pictures Corporation     USA      Rob Reiner
# 1   6000000.0                      Paramount Pictures     USA     John Hughes
# 2  15000000.0                      Paramount Pictures     USA      Tony Scott
# 3  18500000.0  Twentieth Century Fox Film Corporation     USA   James Cameron
# 4   9000000.0                    Walt Disney Pictures     USA  Randal Kleiser
#
#        genre        gross                      name rating    released  \
# 0  Adventure   52287414.0               Stand by Me      R  1986-08-22
# 1     Comedy   70136369.0  Ferris Bueller's Day Off  PG-13  1986-06-11
# 2     Action  179800601.0                   Top Gun     PG  1986-05-16
# 3     Action   85160248.0                    Aliens      R  1986-07-18
# 4  Adventure   18564613.0   Flight of the Navigator     PG  1986-08-01
#
#    runtime  score               star   votes         writer  year
# ...

# %%
df.isnull().sum()
# Out:
# budget      0
# company     0
# country     0
# director    0
# genre       0
# gross       0
# name        0
# rating      0
# released    0
# runtime     0
# score       0
# star        0
# votes       0
# writer      0
# year        0
# dtype: int64

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{}-{}%'.format(col, pct_missing))
# Out:
# budget-0.0%
# company-0.0%
# country-0.0%
# director-0.0%
# genre-0.0%
# gross-0.0%
# name-0.0%
# rating-0.0%
# released-0.0%
# runtime-0.0%
# score-0.0%
# star-0.0%
# votes-0.0%
# writer-0.0%
# year-0.0%

# %%
#data type of the columns
df.head()
# Out:
#        budget                                 company country        director  \
# 0   8000000.0           Columbia Pictures Corporation     USA      Rob Reiner
# 1   6000000.0                      Paramount Pictures     USA     John Hughes
# 2  15000000.0                      Paramount Pictures     USA      Tony Scott
# 3  18500000.0  Twentieth Century Fox Film Corporation     USA   James Cameron
# 4   9000000.0                    Walt Disney Pictures     USA  Randal Kleiser
#
#        genre        gross                      name rating    released  \
# 0  Adventure   52287414.0               Stand by Me      R  1986-08-22
# 1     Comedy   70136369.0  Ferris Bueller's Day Off  PG-13  1986-06-11
# 2     Action  179800601.0                   Top Gun     PG  1986-05-16
# 3     Action   85160248.0                    Aliens      R  1986-07-18
# 4  Adventure   18564613.0   Flight of the Navigator     PG  1986-08-01
#
#    runtime  score               star   votes         writer  year
# ...

# %%
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['budget'].astype('int64')

# %%
df.head()
# Out:
#      budget                                 company country        director  \
# 0   8000000           Columbia Pictures Corporation     USA      Rob Reiner
# 1   6000000                      Paramount Pictures     USA     John Hughes
# 2  15000000                      Paramount Pictures     USA      Tony Scott
# 3  18500000  Twentieth Century Fox Film Corporation     USA   James Cameron
# 4   9000000                    Walt Disney Pictures     USA  Randal Kleiser
#
#        genre     gross                      name rating    released  runtime  \
# 0  Adventure   8000000               Stand by Me      R  1986-08-22       89
# 1     Comedy   6000000  Ferris Bueller's Day Off  PG-13  1986-06-11      103
# 2     Action  15000000                   Top Gun     PG  1986-05-16      110
# 3     Action  18500000                    Aliens      R  1986-07-18      137
# 4  Adventure   9000000   Flight of the Navigator     PG  1986-08-01       90
#
# ...

# %%
df['year_correct'] = df['released'].astype(str).str[:4]

# %%
df.head()
# Out:
#      budget                                 company country        director  \
# 0   8000000           Columbia Pictures Corporation     USA      Rob Reiner
# 1   6000000                      Paramount Pictures     USA     John Hughes
# 2  15000000                      Paramount Pictures     USA      Tony Scott
# 3  18500000  Twentieth Century Fox Film Corporation     USA   James Cameron
# 4   9000000                    Walt Disney Pictures     USA  Randal Kleiser
#
#        genre     gross                      name rating    released  runtime  \
# 0  Adventure   8000000               Stand by Me      R  1986-08-22       89
# 1     Comedy   6000000  Ferris Bueller's Day Off  PG-13  1986-06-11      103
# 2     Action  15000000                   Top Gun     PG  1986-05-16      110
# 3     Action  18500000                    Aliens      R  1986-07-18      137
# 4  Adventure   9000000   Flight of the Navigator     PG  1986-08-01       90
#
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#      budget                                 company country        director  \
# 0   8000000           Columbia Pictures Corporation     USA      Rob Reiner
# 1   6000000                      Paramount Pictures     USA     John Hughes
# 2  15000000                      Paramount Pictures     USA      Tony Scott
# 3  18500000  Twentieth Century Fox Film Corporation     USA   James Cameron
# 4   9000000                    Walt Disney Pictures     USA  Randal Kleiser
#
#        genre     gross                      name rating    released  runtime  \
# 0  Adventure   8000000               Stand by Me      R  1986-08-22       89
# 1     Comedy   6000000  Ferris Bueller's Day Off  PG-13  1986-06-11      103
# 2     Action  15000000                   Top Gun     PG  1986-05-16      110
# 3     Action  18500000                    Aliens      R  1986-07-18      137
# 4  Adventure   9000000   Flight of the Navigator     PG  1986-08-01       90
#
# ...

# %%
df2 = df.sort_values(by='gross', ascending=False)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#to check the distinct count for sort values

df['company'].drop_duplicates().sort_values(ascending=False)
# Out:
# 5288                                          micro_scope
# 3486                                             i5 Films
# 6084                                                 erbp
# 3225                                       double A Films
# 2707                          Zucker Brothers Productions
# 1495                                   Zeta Entertainment
# 5905                                 Zentropa Productions
# 5917                        Zentropa International Norway
# 2742                              Zentropa Entertainments
# 329                                  Zenith Entertainment
# 4710                                      Zazen Produ��es
# 542                              Zanuck/Brown Productions
# 698                                   Zanuck Company, The
# 499                           Zacharias-Buhai Productions
# 4687                           Young Hannibal Productions
# 5084                                          Yellow Bird
# ...

# %% [markdown]
# # to check the correlation

# %%
num_data=df.select_dtypes(include=np.number)

# %%
num_data.head()
# Out:
#        budget        gross  runtime  score   votes  year
# 0   8000000.0   52287414.0       89    8.1  299174  1986
# 1   6000000.0   70136369.0      103    7.8  264740  1986
# 2  15000000.0  179800601.0      110    6.9  236909  1986
# 3  18500000.0   85160248.0      137    8.4  540152  1986
# 4   9000000.0   18564613.0       90    6.9   36636  1986

# %%
num_data.columns
# Out:
# Index(['budget', 'gross', 'runtime', 'score', 'votes', 'year'], dtype='object')

# %%
cat_data=df.select_dtypes(exclude=np.number)

# %%
cat_data.head()
# Out:
#                             company      country        director      genre  \
# 4631           Walt Disney Pictures          USA  Gore Verbinski     Action
# 5293  Walt Disney Animation Studios          USA    Nathan Greno  Animation
# 4637              Columbia Pictures          USA       Sam Raimi     Action
# 6624                 Marvel Studios          USA   Anthony Russo     Action
# 6194                New Line Cinema  New Zealand   Peter Jackson  Adventure
#
#                                            name rating    released  \
# 4631   Pirates of the Caribbean: At World's End  PG-13  2007-05-25
# 5293                                    Tangled     PG  2010-11-24
# 4637                               Spider-Man 3  PG-13  2007-05-04
# 6624                 Captain America: Civil War  PG-13  2016-05-06
# 6194  The Hobbit: The Battle of the Five Armies  PG-13  2014-12-17
#
#                star              writer year_correct
# ...

# %%
plt.scatter(x = df['budget'], y = df['gross'])
plt.xlabel('budget')
plt.ylabel('gross')
plt.title('budget vs gross')
# Out:
# Text(0.5, 1.0, 'budget vs gross')

# %%
#plot budget vs gross using seaborn
sns.regplot(data = df, x = 'budget', y = 'gross', scatter_kws={'color':'red'}, line_kws={'color':'blue'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
#Lets start looking at correlation

df.corr()
# Out:
#            budget     gross   runtime     score     votes      year
# budget   1.000000  0.712196  0.268226  0.042145  0.503924  0.291009
# gross    0.712196  1.000000  0.224579  0.165693  0.662457  0.191548
# runtime  0.268226  0.224579  1.000000  0.395343  0.317399  0.087639
# score    0.042145  0.165693  0.395343  1.000000  0.393607  0.105276
# votes    0.503924  0.662457  0.317399  0.393607  1.000000  0.229304
# year     0.291009  0.191548  0.087639  0.105276  0.229304  1.000000

# %%
#high correlation between budget and gross

# %%
correlation_matrix = df.corr()

# %%
sns.heatmap(correlation_matrix, annot=True)
plt.xlabel('movie Feature')
plt.ylabel('movie Feature')
plt.title('correlation_matrix')
plt.show()

# %%
df_numerized = cat_data

for i in df_numerized:
    df_numerized[i] = df_numerized[i].astype('category')

# %%
for i in df_numerized:
    df_numerized[i] = df_numerized[i].cat.codes

# %%
df_numerized.head()
# Out:
#       company  country  director  genre  name  rating  released  star  writer  \
# 4631     2122       54       914      0  3890       7      1619  1181    3844
# 5293     2119       54      1882      2  4877       6      1876  1536     749
# 4637      664       54      2317      0  4632       7      1615  2334    3541
# 6624     1491       54       160      0   945       7      2320   392     651
# 6194     1582       34      2045      1  5420       7      2207   911    1231
#
#       year_correct
# 4631            21
# 5293            24
# 4637            21
# 6624            30
# 6194            28

# %%
df_numerized_corr = df_numerized.corr()

# %%
sns.heatmap(df_numerized_corr, annot=True)
# Out:
# <AxesSubplot:>
